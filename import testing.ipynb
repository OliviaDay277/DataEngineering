# %%
import pandas as pd
import numpy as np

# %%
import re

# %%
df=pd.read_csv("Aranesp_all_records.csv",index_col=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['batch_number', 'manufacture_date', 'mfg_site_bldg', 'mfg_stage_code',
#        'mfg_stage_code_desc', 'product_name', 'generic_name',
#        'lims_trade_name', 'spec_number', 'specification', 'test_site',
#        'component', 'number_value', 'text_value'],
#       dtype='object')

# %%
df["test_site_str"]=pd.Series(map(str,df["test_site"]))

# %%
df_adl=df[pd.Series(map(lambda x: "ADL" in x, df["test_site_str"]))]

# %%
df_aml=df[pd.Series(map(lambda x: "AML" in x, df["test_site_str"]))]

# %%
print(len(df_aml))
print(len(df_adl))
# Out:
# 291826
# 98735

# %%
tt=pd.merge(df_adl,df_aml[["test_site","number_value","text_value",'spec_number',"batch_number","component",'mfg_stage_code']],\
            on=["batch_number","component",'mfg_stage_code'],how="inner")

# %%
bb=pd.merge(df[df["test_site"]=="AML"],df[df["test_site"]=="ADL"],on=["batch_number","component",'mfg_stage_code'])

# %%
print(len(pd.unique(df_aml["batch_number"])))
print(len(pd.unique(df_adl["batch_number"])))
# Out:
# 1561
# 251

# %%
df_aml[["batch_number","component",'mfg_stage_code']].drop_duplicates()
# Out:
#        batch_number                  component mfg_stage_code
# 66          1029245    Sample Strength (ug/mL)            FDP
# 67          1029245                   Identity            FDP
# 72          1029452    Sample Strength (ug/mL)            FDP
# 73          1029452                   Identity            FDP
# 74          1033902    Sample Strength (ug/mL)            FDP
# 75          1033902                   Identity            FDP
# 78          1035234    Sample Strength (ug/mL)            FDP
# 81          1035234                   Identity            FDP
# 82          1036166                   Identity            FDP
# 83          1036166    Sample Strength (ug/mL)            FDP
# 88          1038812                   Identity            FDP
# 89          1038812    Sample Strength (ug/mL)            FDP
# 90          1039537    Sample Strength (ug/mL)            FDP
# 93          1039537                   Identity            FDP
# ...

# %%
len(df_aml.drop_duplicates())
# Out:
# 18770

# %%
re.search("ADL","ADL1235")
# Out:
# <_sre.SRE_Match object; span=(0, 3), match='ADL'>

# %%
df[df["test_site"]=="AML"]
# Out:
#        batch_number     manufacture_date mfg_site_bldg mfg_stage_code  \
# 22919    0010071281  2010-11-17 00:00:00       USTO:20            IDP
# 78820    0010248929  2015-07-27 00:00:00     PRJU:APR1             DP
# 78821    0010248929  2015-07-27 00:00:00     PRJU:APR1             DP
# 78822    0010248929  2015-07-27 00:00:00     PRJU:APR1             DP
# 78823    0010248929  2015-07-27 00:00:00     PRJU:APR1             DP
# 78824    0010248929  2015-07-27 00:00:00     PRJU:APR1             DP
# 80128    0010249536  2015-07-01 00:00:00    PRJU:APR14             DP
# 80129    0010249536  2015-07-01 00:00:00    PRJU:APR14             DP
# 80130    0010249536  2015-07-01 00:00:00    PRJU:APR14             DP
# 80131    0010249536  2015-07-01 00:00:00    PRJU:APR14             DP
# 83211    0010252280  2015-07-28 00:00:00    PRJU:APR14             DP
# 83212    0010252280  2015-07-28 00:00:00    PRJU:APR14             DP
# ...
