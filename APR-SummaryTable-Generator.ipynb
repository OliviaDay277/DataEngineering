# %% [markdown]
# #### 1. Generate raw dataset without OOS
# #### 2. Generate summary table(Normality stats, original Ppk)
# #### 3. Prepare the subset of raw dataset containing several parameters for JMP

# %%
import pandas as pd
import numpy as np

import os

from scipy.stats import anderson
from scipy.stats import kstest
from scipy.stats import shapiro

def kurt(values):
    n=len(values)
    if (n<4): 
        result=np.nan
    else:
        sample_mean=np.mean(values)
        sample_std=np.std(values,ddof=1)
        result=np.sum(((values-sample_mean)/sample_std)**4)*n*(n+1)/((n-1)*(n-2)*(n-3))-3*(n-1)**2/((n-2)*(n-3))
    return(result)

def skewness(values):
    n=len(values)
    if (n<3):
        result=np.nan
    else:
        sample_mean=np.mean(values)
        sample_std=np.std(values,ddof=1)
        result=n*np.sum(((values-sample_mean)/sample_std)**3)/((n-1)*(n-2))
    return(result)

def CV(values):
    sample_mean=np.mean(values)
    sample_std=np.std(values,ddof=1)
    return(100*sample_std/sample_mean)

def ppk_single_row(values,ual,lal,spec_status):
    if spec_status==0:
        ppk=np.minimum(float(ual)-np.mean(values),np.mean(values)-float(lal) )/(3*np.std(values,ddof=1))
    else:
        if spec_status==1:
            ppk=(float(ual)-np.mean(values))/(3*np.std(values,ddof=1))
        else:
            if spec_status==-1:
                ppk=(np.mean(values)-float(lal))/(3*np.std(values,ddof=1))
            else:
                ppk="NA3"
    return(ppk)

def add_specside(df):
    #no spec default
    df["spec status"]=None
    #two specs
    df["spec status"].loc[(df.UAL!=".") & (df.LAL!=".")]=0
    #only lower spec
    df["spec status"].loc[(df.UAL==".") & (df.LAL!=".")]=-1
    #only upper spec
    df["spec status"].loc[(df.UAL!=".") & (df.LAL==".")]=1
    
def add_clside(df):
    #no spec default
    df["ctrl status"]=None
    #two specs
    df["ctrl status"].loc[(df.LCL!=".") & (df.UCL!=".")]=0
    #only lower spec
    df["ctrl status"].loc[(df.UCL==".") & (df.LCL!=".")]=-1
    #only upper spec
    df["ctrl status"].loc[(df.UCL!=".") & (df.LCL==".")]=1

def df_colname_unify(df):
    df=df.rename(columns={"ual":"UAL","lal":"LAL","lcl":"LCL","ucl":"UCL"})

def quanti_quali_namelists(df):
    
    qualitative_paras=list(pd.unique(df["parameter name"][df['result type']=="TEXT"]))

    quantitative_paras=list(pd.unique(df["parameter name"][df['result type']=="Number"]))
    
    return(quantitative_paras,qualitative_paras)

def para_unit_combi_df(df):
    para_unit_combi=df[["parameter name","unit procedure"]].copy().drop_duplicates().reset_index(drop=True)
    para_unit_combi=para_unit_combi.sort_values(by=["unit procedure","parameter name"])
    return(para_unit_combi)

#only use a quantitative dataset as the input
def spec_correction_rawset(df,para_unit_pair_df):
    for i in range(len(para_unit_pair_df)):
        para=para_unit_pair_df["parameter name"].iloc[i]
        unit=para_unit_pair_df["unit procedure"].iloc[i]
        
        sub_df_len=len(df.loc[(df['parameter name']==para) &(df["unit procedure"]==unit)])
        
        #more than one row, needs spec correction
        if (sub_df_len>1):
           
            #could loop using the uniq combination of unit and para, otherwise add this row number check to avoid void error
            ual=df[(df['parameter name']==para) &(df["unit procedure"]==unit)].UAL.iloc[-1]
        
            lal=df[(df['parameter name']==para) &(df["unit procedure"]==unit)].LAL.iloc[-1]
            df["UAL"].loc[(df['parameter name']==para) &(df["unit procedure"]==unit)]=ual
            df["LAL"].loc[(df['parameter name']==para) &(df["unit procedure"]==unit)]=lal

def find_oos_index(df):
    df_twospecs=df[df["spec status"]==0]
    df_uspecs=df[df["spec status"]==1]
    df_lspecs=df[df["spec status"]==-1]
    
    #Find the indexes of OOS rows, try to do this in SQL
    twospecs_rows_oos=list(df_twospecs.index[(df_twospecs["value_num(recorded/full precision)"]<df_twospecs.LAL)\
                    |(df_twospecs["value_num(recorded/full precision)"]>df_twospecs.UAL)])

    uspecs_rows_oos=list(df_uspecs.index[(df_uspecs["value_num(recorded/full precision)"]>df_uspecs.UAL)])

    lspecs_rows_oos=list(df_lspecs.index[(df_lspecs["value_num(recorded/full precision)"]<df_lspecs.LAL)])
    
    return(list(set(twospecs_rows_oos+uspecs_rows_oos+lspecs_rows_oos)))

def find_oot_index(df):
    df_twocls=df[df["ctrl status"]==0]
    df_ucl=df[df["ctrl status"]==1]
    df_lcl=df[df["ctrl status"]==-1]
    
    twocls_rows_oot=list(df_twocls.index[(df_twocls["value_num(recorded/full precision)"]<df_twocls.LCL)\
                |(df_twocls["value_num(recorded/full precision)"]>df_twocls.UCL)])

    ucls_rows_oot=list(df_ucl.index[(df_ucl["value_num(recorded/full precision)"]>df_ucl.UCL)])

    lcls_rows_oot=list(df_lcl.index[(df_lcl["value_num(recorded/full precision)"]<df_lcl.LCL)])

    return(list(set(twocls_rows_oot+ucls_rows_oot+lcls_rows_oot)))

#change the threshold(30) if we allow smaller sample size after excluding the OOS
#input_type can be "" or "_no_OOS" or "no_OOST", etc, used to define the the column name
def aggre_summary_df_generator(df, para_unit_pair_df, input_type):
    
    #initialize the summary output df
    aggre_stats_output_df=pd.DataFrame(columns=["parameter name",'unit procedure',#"PRDS",#\
                                           "N","mean","median","STD","variance","UAL","LAL","spec status","Ppk"+input_type,\
                                           "skewness","kurtosis","CV",#"anderson-darling"\
                                            "shapiro","KS"\
                                              ])
    for i in range(len(para_unit_pair_df)):
        
        para=para_unit_pair_df["parameter name"].iloc[i]
        unit=para_unit_pair_df["unit procedure"].iloc[i]
        
        single_df=df.loc[(df['parameter name']==para) &(df["unit procedure"]==unit)].copy().sort_values(by="parameter date") 
        single_df_values=single_df["value_num(recorded/full precision)"]  
        
        ual=single_df.UAL.iloc[-1]
        lal=single_df.LAL.iloc[-1]
        spec_status=single_df["spec status"].iloc[-1]

        if (len(single_df)<30):
            ppk="NA1"

        if( (len(single_df)>=30) and (len(pd.unique(single_df_values)<5)) ):
            ppk="NA2"

        #NA3: no specs is addressed inside the ppk_single_row
           
        if ((len(single_df)>=30) and (len(pd.unique(single_df_values)>=5)) ):
 
            #prds=pd.unique(single_df["parameter detail"])
            
            ppk=ppk_single_row(single_df_values,ual,lal,spec_status)
        if (len(single_df)<4):
            shap=np.nan
            ks=np.nan
        else:
            shap=shapiro(single_df_values)[1]
            ks=kstest(single_df_values,"norm")[1]
        
        aggre_stats_output_df=aggre_stats_output_df.append({\
                        'parameter name':para,\
                        "unit procedure":unit,\
                        #"PRDS":prds,
                        "N":len(single_df_values),\
                        "mean":np.mean(single_df_values),\
                        "STD":np.std(single_df_values,ddof=1),\
                        "variance":np.var(single_df_values,ddof=1),\
                        "median":np.median(single_df_values),\
                        "LAL":lal, "UAL":ual,      \
                        "spec status":spec_status ,\
                        "Ppk"+input_type: ppk,\
                        "skewness":skewness(single_df_values),\
                        "kurtosis":kurt(single_df_values),\
                        "CV":CV(single_df_values),\
                        #"Anderson-Darling":anderson(sub_df),\
                        "shapiro":shap,\
                        #the p value of shapiro
                       "KS":ks},\
                        #the p value of kstest
                                    ignore_index=True)
    return(aggre_stats_output_df)

def JMP_single_para_subset_generator(para_unit_pair_df, raw_df, folder_path):
    os.chdir(folder_path)
    for i in range(len(para_unit_pair_df)):
        para=para_unit_pair_df["parameter name"].iloc[i]
        unit=para_unit_pair_df["unit procedure"].iloc[i]
        single_subset=raw_df[(raw_df["parameter name"]==para)&(raw_df["unit procedure"]==unit)].copy()
        single_subset.to_csv(para+"-"+unit+"JMP.csv", index=False)
    
    return

# %%
aggre_summary_df_generator(test, para_unit_pair_df,"_no_OOS")
# Out:
#                                         parameter name  \
# 0                                             Chloride
# 1                                          Immunoassay
# 2                                    In vitro bioassay
# 3                                 Methionine Oxidation
# 4                                            Phosphate
# 5                                       Polysorbate 80
# 6                                              SE-HPLC
# 7                        Subvisible Particles >= 10 um
# 8                        Subvisible Particles >= 25 um
# 9                              Volume (0.3 mL Syringe)
# 10                             Volume (0.4 mL Syringe)
# 11                             Volume (0.5 mL Syringe)
# 12                                                  pH
# 13                                            Chloride
# 14                                         Immunoassay
# 15                                   In vitro bioassay
# 16                                Methionine Oxidation
# 17                                           Phosphate
# 18                                      Polysorbate 80
# 19                       Subvisible Particles >= 10 um
# 20                       Subvisible Particles >= 25 um
# 21                             Volume (0.3 mL Syringe)
# 22                             Volume (0.4 mL Syringe)
# 23                             Volume (0.5 mL Syringe)
# 24                             Volume (0.6 mL Syringe)
# 25                            Volume (0.65 mL Syringe)
# 26                             Volume (1.0 mL Syringe)
# 27                                                  pH
# 28                                            Chloride
# 29                                         Immunoassay
# ..                                                 ...
# 96                            Volume (0.65 mL Syringe)
# 97                             Volume (1.0 mL Syringe)
# 98                                Volume (1.0 mL Vial)
# 99                                                  pH
# 100                               Methionine Oxidation
# 101                           CHO Proteins Immunoassay
# 102  Carbohydrate Profile (sialo) oligosaccharide m...
# 103  Carbohydrate Profile (sialo) oligosaccharide m...
# 104  Carbohydrate Profile (sialo) oligosaccharide m...
# 105                                  In Vitro Bioassay
# 106              Isoelectric Focusing: Isoform 21 + 22
# 107                   Isoelectric Focusing: Isoform 22
# 108             Isoelectric Focusing: Isoforms 19 + 20
# 109            Isoelectric Focusing: Isoforms 19 to 22
# 110                              Protein Concentration
# 111                     Size-exclusion HPLC: % Monomer
# 112                                                 pH
# 113                                            SE-HPLC
# 114                                           Chloride
# 115                                        Immunoassay
# 116                                  In vitro bioassay
# 117                               Methionine Oxidation
# 118                                          Phosphate
# 119                                            SE-HPLC
# 3            103          IEDL:ADL9-DP-ADL              .
# 4            104          IEDL:ADL9-DP-ADL              .
# 5            105          IEDL:ADL9-DP-ADL              .
# 6            106          IEDL:ADL9-DP-ADL              .
# 7            107          IEDL:ADL9-DP-ADL              .
# 8            108          IEDL:ADL9-DP-ADL              .
# 9            109          IEDL:ADL9-DP-ADL              .
# 10           110          IEDL:ADL9-DP-ADL              .
# 11           111          IEDL:ADL9-DP-ADL              .
# 12           112          IEDL:ADL9-DP-ADL              .
# 13           113          IEDL:ADL9-DP-ADL              .
# 14           114          IEDL:ADL9-DP-ADL              .
# 15           115          IEDL:ADL9-DP-ADL              .
# 16           116          IEDL:ADL9-DP-ADL              .
# 17           117          IEDL:ADL9-DP-ADL              .
# 18           118          IEDL:ADL9-DP-ADL              .
# 19           119          IEDL:ADL9-DP-ADL              .
# 20           120          IEDL:ADL9-DP-ADL              .
# 21           121          IEDL:ADL9-DP-ADL              .
# 22           122          IEDL:ADL9-DP-ADL              .
# 23           123          IEDL:ADL9-DP-ADL              .
# 24           124          IEDL:ADL9-DP-ADL              .
# 25           125          IEDL:ADL9-DP-ADL              .
# 26           126          IEDL:ADL9-DP-ADL              .
# 27           127          IEDL:ADL9-DP-ADL              .
# 28           128          IEDL:ADL9-DP-ADL              .
# 29           129          IEDL:ADL9-DP-ADL              .
# ...          ...                       ...            ...
# 4033        6080            USTO:20-DP-ATO              .
# 4034        6081            USTO:20-DP-ATO              .
# 4035        6082            USTO:20-DP-ATO              .
# 4036        6083            USTO:20-DP-ATO              .
# 4037        6084            USTO:20-DP-ATO              .
# 4038        6085            USTO:20-DP-ATO              .
# 4039        6086            USTO:20-DP-ATO              .
# 4040        6087            USTO:20-DP-ATO              .
# 4041        6088            USTO:20-DP-ATO              .
# 4042        6089            USTO:20-DP-ATO              .
# 4043        6090            USTO:20-DP-ATO              .
# 4044        6091            USTO:20-DP-ATO              .
# 4045        6092            USTO:20-DP-ATO              .
# 4046        6093            USTO:20-DP-ATO              .
# 4047        6094            USTO:20-DP-ATO              .
# 4048        6095            USTO:20-DP-ATO              .
# 4049        6096            USTO:20-DP-ATO              .
# 4050        6097            USTO:20-DP-ATO              .
# 4051        6098            USTO:20-DP-ATO              .
# 4052        6099  USTO:20-DP-Raw Materials              .
# 4053        6100  USTO:20-DP-Raw Materials              .
# 4054        6101  USTO:20-DP-Raw Materials              .
# 4055        6102  USTO:20-DP-Raw Materials              .
# 4056        6103  USTO:20-DP-Raw Materials              .
# 4057        6104  USTO:20-DP-Raw Materials              .
# 4058        6105  USTO:20-DP-Raw Materials              .
# 4059        6106  USTO:20-DP-Raw Materials              .
# 4060        6107  USTO:20-DP-Raw Materials              .
# 4061        6108  USTO:20-DP-Raw Materials              .
# 4062        6109  USTO:20-DP-Raw Materials              .
#
#                parameter name parameter detail run number batch number  \
# 0                    Chloride      PRDS-000444   10340208     10340208
# 1                    Chloride      PRDS-000443   10340209     10340209
# 2                    Chloride      PRDS-000443   10344080     10344080
# 3                    Chloride      PRDS-000444   10340210     10340210
# 4                    Chloride      PRDS-000443   10340211     10340211
# 5                    Chloride      PRDS-000449   10345848     10345848
# 1             2017-07-13    2017-07-10     2017-07-13     ...       LIN
# 2             2017-07-18    2017-07-18     2017-07-18     ...       LIN
# 3             2017-07-19    2017-07-17     2017-07-19     ...       LIN
# 4             2017-07-25    2017-07-17     2017-07-25     ...       LIN
# 5             2017-07-31    2017-07-31     2017-07-31     ...       LIN
# 6             2017-08-02    2017-07-27     2017-08-02     ...       LIN
# 7             2017-09-14    2017-09-13     2017-09-14     ...       LIN
# 8             2017-09-25    2017-09-23     2017-09-25     ...       LIN
# 9             2017-10-02    2017-10-02     2017-10-02     ...       LIN
# 10            2017-10-04    2017-09-25     2017-10-04     ...       LIN
# 11            2017-10-05    2017-09-27     2017-10-05     ...       LIN
# 12            2017-10-09    2017-10-02     2017-10-09     ...       LIN
# 13            2017-10-10    2017-10-04     2017-10-10     ...       LIN
# 14            2017-10-12    2017-10-11     2017-10-12     ...       LIN
# 15            2017-10-20    2017-10-16     2017-10-20     ...       LIN
# 16            2017-11-14    2017-11-07     2017-11-14     ...       LIN
# 17            2017-11-20    2017-11-20     2017-11-20     ...       LIN
# 18            2017-11-22    2017-11-22     2017-11-22     ...       LIN
# 19            2017-11-23    2017-11-21     2017-11-23     ...       LIN
# 20            2017-11-27    2017-11-26     2017-11-27     ...       LIN
# 21            2017-11-28    2017-11-27     2017-11-28     ...       LIN
# 22            2017-11-30    2017-11-30     2017-11-30     ...       LIN
# 23            2017-12-01    2017-12-01     2017-12-01     ...       LIN
# 24            2017-12-05    2017-12-04     2017-12-05     ...       LIN
# 25            2017-12-08    2017-12-08     2017-12-08     ...       LIN
# 26            2018-01-08    2018-01-08     2018-01-08     ...       LIN
# 27            2018-01-09    2018-01-09     2018-01-09     ...       LIN
# 28            2018-01-11    2018-01-11     2018-01-11     ...       LIN
# 29            2018-01-16    2018-01-15     2018-01-16     ...       LIN
# ...                  ...           ...            ...     ...       ...
# 4033          2012-02-20    2012-02-17     2012-02-20     ...       LIN
# 4034          2012-03-23    2012-03-22     2012-03-23     ...       LIN
# 4035          2013-08-26    2013-08-26     2013-08-26     ...       LIN
# 4036          2015-02-10    2015-02-10     2015-02-10     ...       LIN
# 4037          2016-07-18    2016-07-18     2016-07-18     ...       LIN
# 4038          2010-04-28    2010-04-28     2010-04-28     ...       LIN
# 4039          2010-06-18    2010-06-18     2010-06-18     ...       LIN
# 4040          2010-06-18    2010-06-18     2010-06-18     ...       LIN
# 4041          2011-08-04    2011-08-04     2011-08-04     ...       LIN
# 4042          2011-12-16    2011-12-15     2011-12-16     ...       LIN
# 4043          2012-02-20    2012-02-17     2012-02-20     ...       LIN
# 4044          2012-03-23    2012-03-22     2012-03-23     ...       LIN
# 4045          2013-03-06    2013-03-06     2013-03-06     ...       LIN
# 4046          2013-08-26    2013-08-26     2013-08-26     ...       LIN
# 4047          2014-04-28    2014-04-28     2014-04-28     ...       LIN
# 4048          2015-02-10    2015-02-10     2015-02-10     ...       LIN
# 4049          2015-08-07    2015-08-07     2015-08-07     ...       LIN
# 4050          2016-07-18    2016-07-18     2016-07-18     ...       LIN
# 4051          2016-12-08    2016-12-08     2016-12-08     ...       LIN
# 4052          2011-08-04    2011-08-04     2011-08-04     ...       LIN
# 4053          2011-12-16    2011-12-15     2011-12-16     ...       LIN
# 4054          2012-02-20    2012-02-17     2012-02-20     ...       LIN
# 4055          2012-03-23    2012-03-22     2012-03-23     ...       LIN
# 4056          2013-03-06    2013-03-06     2013-03-06     ...       LIN
# 4057          2013-08-26    2013-08-26     2013-08-26     ...       LIN
# 4058          2014-04-28    2014-04-28     2014-04-28     ...       LIN
# 4059          2015-02-10    2015-02-10     2015-02-10     ...       LIN
# 4060          2015-08-07    2015-08-07     2015-08-07     ...       LIN
# 4061          2016-07-18    2016-07-18     2016-07-18     ...       LIN
# 4062          2016-12-08    2016-12-08     2016-12-08     ...       LIN
#
#       summary table  disposition_date result type source_system  \
# 0                 .                 .      Number        SMLIMS
# 1                 .                 .      Number        SMLIMS
# 2                 .                 .      Number        SMLIMS
# 3                 .                 .      Number        SMLIMS
# 4                 .                 .      Number        SMLIMS
# 5                 .                 .      Number        SMLIMS
# 6                 .                 .      Number        SMLIMS
# 7                 .                 .      Number        SMLIMS
# 8                 .                 .      Number        SMLIMS
# 9                 .                 .      Number        SMLIMS
# 10                .                 .      Number        SMLIMS
# 11                .                 .      Number        SMLIMS
# 12                .                 .      Number        SMLIMS
# 13                .                 .      Number        SMLIMS
# 14                .                 .      Number        SMLIMS
# 15                .                 .      Number        SMLIMS
# 16                .                 .      Number        SMLIMS
# 17                .                 .      Number        SMLIMS
# 18                .                 .      Number        SMLIMS
# 19                .                 .      Number        SMLIMS
# 20                .                 .      Number        SMLIMS
# 21                .                 .      Number        SMLIMS
# 22                .                 .      Number        SMLIMS
# 23                .                 .      Number        SMLIMS
# 24                .                 .      Number        SMLIMS
# 25                .                 .      Number        SMLIMS
# 26                .                 .      Number        SMLIMS
# 27                .                 .      Number        SMLIMS
# 28                .                 .      Number        SMLIMS
# 29                .                 .      Number        SMLIMS
# ...             ...               ...         ...           ...
# 4033              .                 .      Number        SMLIMS
# 4034              .                 .      Number        SMLIMS
# 4035              .                 .      Number        SMLIMS
# 4036              .                 .      Number        SMLIMS
# 4037              .                 .      Number        SMLIMS
# 4038              .                 .      Number        SMLIMS
# 4039              .                 .      Number        SMLIMS
# 4040              .                 .      Number        SMLIMS
# 4041              .                 .      Number        SMLIMS
# 4042              .                 .      Number        SMLIMS
# 4043              .                 .      Number        SMLIMS
# 4044              .                 .      Number        SMLIMS
# 4045              .                 .      Number        SMLIMS
# 4046              .                 .      Number        SMLIMS
# 4047              .                 .      Number        SMLIMS
# 4048              .                 .      Number        SMLIMS
# 4049              .                 .      Number        SMLIMS
# 4050              .                 .      Number        SMLIMS
# 4051              .                 .      Number        SMLIMS
# 4052              .                 .      Number        SMLIMS
# 4053              .                 .      Number        SMLIMS
# 4054              .                 .      Number        SMLIMS
# 4055              .                 .      Number        SMLIMS
# 4056              .                 .      Number        SMLIMS
# 4057              .                 .      Number        SMLIMS
# 4058              .                 .      Number        SMLIMS
# 4059              .                 .      Number        SMLIMS
# 4060              .                 .      Number        SMLIMS
# 4061              .                 .      Number        SMLIMS
# 4062              .                 .      Number        SMLIMS
#
#      ctrl_violation action_violation rej_violation spec status ctrl status
# 0                 .                .             .         0.0         NaN
# 1                 .                .             .         0.0         NaN
# 2                 .                .             .         0.0         NaN
# 3                 .                .             .         0.0         NaN
# 4                 .                .             .         0.0         NaN
# 5                 .                .             .         0.0         NaN
# 6                 .                .             .         0.0         NaN
# 7                 .                .             .         0.0         NaN
# 8                 .                .             .         0.0         NaN
# 9                 .                .             .         0.0         NaN
# 10                .                .             .         0.0         NaN
# 11                .                .             .         0.0         NaN
# 12                .                .             .         0.0         NaN
# 13                .                .             .         0.0         NaN
# 14                .                .             .         0.0         NaN
# 15                .                .             .         0.0         NaN
# 16                .                .             .         0.0         NaN
# 17                .                .             .         0.0         NaN
# 18                .                .             .         0.0         NaN
# 19                .                .             .         0.0         NaN
# 20                .                .             .         0.0         NaN
# 21                .                .             .         0.0         NaN
# 22                .                .             .         0.0         NaN
# 23                .                .             .         0.0         NaN
# 24                .                .             .         0.0         NaN
# 25                .                .             .         0.0         NaN
# 26                .                .             .         0.0         NaN
# 27                .                .             .         0.0         NaN
# 28                .                .             .         0.0         NaN
# 29                .                .             .         0.0         NaN
# ...             ...              ...           ...         ...         ...
# 4033              .                .             .        -1.0         NaN
# 4034              .                .             .        -1.0         NaN
# 4035              .                .             .        -1.0         NaN
# 4036              .                .             .        -1.0         NaN
# 4037              .                .             .        -1.0         NaN
# 4038              .                .             .         0.0         NaN
# 4039              .                .             .         0.0         NaN
# 4040              .                .             .         0.0         NaN
# 4041              .                .             .         0.0         0.0
# 4042              .                .             .         0.0         0.0
# 4043              .                .             .         0.0         0.0
# 4044              .                .             .         0.0         0.0
# 4045              .                .             .         0.0         NaN
# 4046              .                .             .         0.0         NaN
# 4047              .                .             .         0.0         NaN
# 4048              .                .             .         0.0         NaN
# 4049              .                .             .         0.0         NaN
# 4050              .                .             .         0.0         0.0
# 4051              .                .             .         0.0         0.0
# 4052              .                .             .         0.0         0.0
# 4053              .                .             .         0.0         0.0
# 4054              .                .             .         0.0         0.0
# 4055              .                .             .         0.0         0.0
# 4056              .                .             .         0.0         0.0
# 4057              .                .             .         0.0         0.0
# 4058              .                .             .         0.0         NaN
# 4059              .                .             .         0.0         NaN
# 4060              .                .             .         0.0         NaN
# 4061              .                .             .         0.0         0.0
# 4062              .                .             .         0.0         0.0
#
# [4063 rows x 40 columns]

# %%
test
# Out:
#       Unnamed: 0            unit procedure sampling point  \
# 0            100          IEDL:ADL9-DP-ADL              .
# 1            101          IEDL:ADL9-DP-ADL              .
# 2            102          IEDL:ADL9-DP-ADL              .
# 3            103          IEDL:ADL9-DP-ADL              .
# 4            104          IEDL:ADL9-DP-ADL              .
# 5            105          IEDL:ADL9-DP-ADL              .
# 6            106          IEDL:ADL9-DP-ADL              .
# 7            107          IEDL:ADL9-DP-ADL              .
# 8            108          IEDL:ADL9-DP-ADL              .
# 9            109          IEDL:ADL9-DP-ADL              .
# 10           110          IEDL:ADL9-DP-ADL              .
# 11           111          IEDL:ADL9-DP-ADL              .
# 12           112          IEDL:ADL9-DP-ADL              .
# 13           113          IEDL:ADL9-DP-ADL              .
# 14           114          IEDL:ADL9-DP-ADL              .
# 15           115          IEDL:ADL9-DP-ADL              .
# 16           116          IEDL:ADL9-DP-ADL              .
# 17           117          IEDL:ADL9-DP-ADL              .
# 18           118          IEDL:ADL9-DP-ADL              .
# 19           119          IEDL:ADL9-DP-ADL              .
# 20           120          IEDL:ADL9-DP-ADL              .
# 21           121          IEDL:ADL9-DP-ADL              .
# 22           122          IEDL:ADL9-DP-ADL              .
# 23           123          IEDL:ADL9-DP-ADL              .
# 24           124          IEDL:ADL9-DP-ADL              .
# 25           125          IEDL:ADL9-DP-ADL              .
# 26           126          IEDL:ADL9-DP-ADL              .
# 27           127          IEDL:ADL9-DP-ADL              .
# 28           128          IEDL:ADL9-DP-ADL              .
# 29           129          IEDL:ADL9-DP-ADL              .
# ...          ...                       ...            ...
# 4033        6080            USTO:20-DP-ATO              .
# 4034        6081            USTO:20-DP-ATO              .
# 4035        6082            USTO:20-DP-ATO              .
# 4036        6083            USTO:20-DP-ATO              .
# 4037        6084            USTO:20-DP-ATO              .
# 4038        6085            USTO:20-DP-ATO              .
# 4039        6086            USTO:20-DP-ATO              .
# 4040        6087            USTO:20-DP-ATO              .
# 4041        6088            USTO:20-DP-ATO              .
# 4042        6089            USTO:20-DP-ATO              .
# 4043        6090            USTO:20-DP-ATO              .
# 4044        6091            USTO:20-DP-ATO              .
# 4045        6092            USTO:20-DP-ATO              .
# 4046        6093            USTO:20-DP-ATO              .
# 4047        6094            USTO:20-DP-ATO              .
# 4048        6095            USTO:20-DP-ATO              .
# 4049        6096            USTO:20-DP-ATO              .
# 4050        6097            USTO:20-DP-ATO              .
# 4051        6098            USTO:20-DP-ATO              .
# 4052        6099  USTO:20-DP-Raw Materials              .
# 4053        6100  USTO:20-DP-Raw Materials              .
# 4054        6101  USTO:20-DP-Raw Materials              .
# 4055        6102  USTO:20-DP-Raw Materials              .
# 4056        6103  USTO:20-DP-Raw Materials              .
# 4057        6104  USTO:20-DP-Raw Materials              .
# 4058        6105  USTO:20-DP-Raw Materials              .
# 4059        6106  USTO:20-DP-Raw Materials              .
# 4060        6107  USTO:20-DP-Raw Materials              .
# 4061        6108  USTO:20-DP-Raw Materials              .
# 4062        6109  USTO:20-DP-Raw Materials              .
#
#                parameter name parameter detail run number batch number  \
# 0                    Chloride      PRDS-000444   10340208     10340208
# 1                    Chloride      PRDS-000443   10340209     10340209
# 2                    Chloride      PRDS-000443   10344080     10344080
# 3                    Chloride      PRDS-000444   10340210     10340210
# 4                    Chloride      PRDS-000443   10340211     10340211
# 5                    Chloride      PRDS-000449   10345848     10345848
# 6                    Chloride      PRDS-000449   10344209     10344209
# 7                    Chloride      PRDS-000444   10349699     10349699
# 8                    Chloride      PRDS-000443   10350648     10350648
# 9                    Chloride      PRDS-000443   10354042     10354042
# 10                   Chloride      PRDS-000449   10350651     10350651
# 11                   Chloride      PRDS-000444   10352209     10352209
# 12                   Chloride      PRDS-000449   10352210     10352210
# 13                   Chloride      PRDS-000449   10352211     10352211
# 14                   Chloride      PRDS-000449   10352213     10352213
# 15                   Chloride      PRDS-000443   10355606     10355606
# 16                   Chloride      PRDS-000444   10358639     10358639
# 17                   Chloride      PRDS-000443   10358746     10358746
# 18                   Chloride      PRDS-000444   10361015     10361015
# 19                   Chloride      PRDS-000439   10359665     10359665
# 20                   Chloride      PRDS-000436   10360049     10360049
# 21                   Chloride      PRDS-000439   10361008     10361008
# 22                   Chloride      PRDS-000446   10361465     10361465
# 23                   Chloride      PRDS-000449   10361911     10361911
# 24                   Chloride      PRDS-000438   10361930     10361930
# 25                   Chloride      PRDS-000438   10362709     10362709
# 26                   Chloride      PRDS-000436   10362560     10362560
# 27                   Chloride      PRDS-000444   10362697     10362697
# 28                   Chloride      PRDS-000449   10362952     10362952
# 29                   Chloride      PRDS-000436   10366881     10366881
# ...                       ...              ...        ...          ...
# 4033  Volume (0.4 mL Syringe)      PRDS-000444   10118380     10118380
# 4034  Volume (0.4 mL Syringe)      PRDS-000444   10122817     10122817
# 4035  Volume (0.4 mL Syringe)      PRDS-000444   10161719     10161719
# 4036  Volume (0.4 mL Syringe)      PRDS-000444   10209049     10209049
# 4037  Volume (0.4 mL Syringe)      PRDS-000444   10252381     10252381
# 4038                       pH      PRDS-000443   10051421     10051421
# 4039                       pH      PRDS-000444   10060937     10060937
# 4040                       pH      PRDS-000443   10060938     10060938
# 4041                       pH      PRDS-000443   10093959     10093959
# 4042                       pH      PRDS-000444   10105827     10105827
# 4043                       pH      PRDS-000444   10118380     10118380
# 4044                       pH      PRDS-000444   10122817     10122817
# 4045                       pH      PRDS-000443   10149520     10149520
# 4046                       pH      PRDS-000444   10161719     10161719
# 4047                       pH      PRDS-000443   10201883     10201883
# 4048                       pH      PRDS-000444   10209049     10209049
# 4049                       pH      PRDS-000443   10235159     10235159
# 4050                       pH      PRDS-000444   10252381     10252381
# 4051                       pH      PRDS-000443   10302677     10302677
# 4052           Polysorbate 80      PRDS-000443   10093959     10093959
# 4053           Polysorbate 80      PRDS-000444   10105827     10105827
# 4054           Polysorbate 80      PRDS-000444   10118380     10118380
# 4055           Polysorbate 80      PRDS-000444   10122817     10122817
# 4056           Polysorbate 80      PRDS-000443   10149520     10149520
# 4057           Polysorbate 80      PRDS-000444   10161719     10161719
# 4058           Polysorbate 80      PRDS-000443   10201883     10201883
# 4059           Polysorbate 80      PRDS-000444   10209049     10209049
# 4060           Polysorbate 80      PRDS-000443   10235159     10235159
# 4061           Polysorbate 80      PRDS-000444   10252381     10252381
# 4062           Polysorbate 80      PRDS-000443   10302677     10302677
#
#      date of manufacture process start parameter date     ...     scale  \
# 0             2017-07-11    2017-07-09     2017-07-11     ...       LIN
# 1             2017-07-13    2017-07-10     2017-07-13     ...       LIN
# 2             2017-07-18    2017-07-18     2017-07-18     ...       LIN
# 3             2017-07-19    2017-07-17     2017-07-19     ...       LIN
# 4             2017-07-25    2017-07-17     2017-07-25     ...       LIN
# 5             2017-07-31    2017-07-31     2017-07-31     ...       LIN
# 6             2017-08-02    2017-07-27     2017-08-02     ...       LIN
# 7             2017-09-14    2017-09-13     2017-09-14     ...       LIN
# 8             2017-09-25    2017-09-23     2017-09-25     ...       LIN
# 9             2017-10-02    2017-10-02     2017-10-02     ...       LIN
# 10            2017-10-04    2017-09-25     2017-10-04     ...       LIN
# 11            2017-10-05    2017-09-27     2017-10-05     ...       LIN
# 12            2017-10-09    2017-10-02     2017-10-09     ...       LIN
# 13            2017-10-10    2017-10-04     2017-10-10     ...       LIN
# 14            2017-10-12    2017-10-11     2017-10-12     ...       LIN
# 15            2017-10-20    2017-10-16     2017-10-20     ...       LIN
# 16            2017-11-14    2017-11-07     2017-11-14     ...       LIN
# 17            2017-11-20    2017-11-20     2017-11-20     ...       LIN
# 18            2017-11-22    2017-11-22     2017-11-22     ...       LIN
# 19            2017-11-23    2017-11-21     2017-11-23     ...       LIN
# 20            2017-11-27    2017-11-26     2017-11-27     ...       LIN
# 21            2017-11-28    2017-11-27     2017-11-28     ...       LIN
# 22            2017-11-30    2017-11-30     2017-11-30     ...       LIN
# 23            2017-12-01    2017-12-01     2017-12-01     ...       LIN
# 24            2017-12-05    2017-12-04     2017-12-05     ...       LIN
# 25            2017-12-08    2017-12-08     2017-12-08     ...       LIN
# 26            2018-01-08    2018-01-08     2018-01-08     ...       LIN
# 27            2018-01-09    2018-01-09     2018-01-09     ...       LIN
# 28            2018-01-11    2018-01-11     2018-01-11     ...       LIN
# 29            2018-01-16    2018-01-15     2018-01-16     ...       LIN
# ...                  ...           ...            ...     ...       ...
# 4033          2012-02-20    2012-02-17     2012-02-20     ...       LIN
# 4034          2012-03-23    2012-03-22     2012-03-23     ...       LIN
# 4035          2013-08-26    2013-08-26     2013-08-26     ...       LIN
# 4036          2015-02-10    2015-02-10     2015-02-10     ...       LIN
# 4037          2016-07-18    2016-07-18     2016-07-18     ...       LIN
# 4038          2010-04-28    2010-04-28     2010-04-28     ...       LIN
# 4039          2010-06-18    2010-06-18     2010-06-18     ...       LIN
# 4040          2010-06-18    2010-06-18     2010-06-18     ...       LIN
# 4041          2011-08-04    2011-08-04     2011-08-04     ...       LIN
# 4042          2011-12-16    2011-12-15     2011-12-16     ...       LIN
# 4043          2012-02-20    2012-02-17     2012-02-20     ...       LIN
# 4044          2012-03-23    2012-03-22     2012-03-23     ...       LIN
# 4045          2013-03-06    2013-03-06     2013-03-06     ...       LIN
# 4046          2013-08-26    2013-08-26     2013-08-26     ...       LIN
# 4047          2014-04-28    2014-04-28     2014-04-28     ...       LIN
# 4048          2015-02-10    2015-02-10     2015-02-10     ...       LIN
# 4049          2015-08-07    2015-08-07     2015-08-07     ...       LIN
# 4050          2016-07-18    2016-07-18     2016-07-18     ...       LIN
# 4051          2016-12-08    2016-12-08     2016-12-08     ...       LIN
# 4052          2011-08-04    2011-08-04     2011-08-04     ...       LIN
# 4053          2011-12-16    2011-12-15     2011-12-16     ...       LIN
# 4054          2012-02-20    2012-02-17     2012-02-20     ...       LIN
# 4055          2012-03-23    2012-03-22     2012-03-23     ...       LIN
# 4056          2013-03-06    2013-03-06     2013-03-06     ...       LIN
# 4057          2013-08-26    2013-08-26     2013-08-26     ...       LIN
# 4058          2014-04-28    2014-04-28     2014-04-28     ...       LIN
# 4059          2015-02-10    2015-02-10     2015-02-10     ...       LIN
# 4060          2015-08-07    2015-08-07     2015-08-07     ...       LIN
# 4061          2016-07-18    2016-07-18     2016-07-18     ...       LIN
# 4062          2016-12-08    2016-12-08     2016-12-08     ...       LIN
#
#       summary table  disposition_date result type source_system  \
# 0                 .                 .      Number        SMLIMS
# 1                 .                 .      Number        SMLIMS
# 2                 .                 .      Number        SMLIMS
# 3                 .                 .      Number        SMLIMS
# 4                 .                 .      Number        SMLIMS
# 5                 .                 .      Number        SMLIMS
# 6                 .                 .      Number        SMLIMS
# 7                 .                 .      Number        SMLIMS
# 8                 .                 .      Number        SMLIMS
# 9                 .                 .      Number        SMLIMS
# 10                .                 .      Number        SMLIMS
# 11                .                 .      Number        SMLIMS
# 12                .                 .      Number        SMLIMS
# 13                .                 .      Number        SMLIMS
# 14                .                 .      Number        SMLIMS
# 15                .                 .      Number        SMLIMS
# 16                .                 .      Number        SMLIMS
# 17                .                 .      Number        SMLIMS
# 18                .                 .      Number        SMLIMS
# 19                .                 .      Number        SMLIMS
# 20                .                 .      Number        SMLIMS
# 21                .                 .      Number        SMLIMS
# 22                .                 .      Number        SMLIMS
# 23                .                 .      Number        SMLIMS
# 24                .                 .      Number        SMLIMS
# 25                .                 .      Number        SMLIMS
# 26                .                 .      Number        SMLIMS
# 27                .                 .      Number        SMLIMS
# 28                .                 .      Number        SMLIMS
# 29                .                 .      Number        SMLIMS
# ...             ...               ...         ...           ...
# 4033              .                 .      Number        SMLIMS
# 4034              .                 .      Number        SMLIMS
# 4035              .                 .      Number        SMLIMS
# 4036              .                 .      Number        SMLIMS
# 4037              .                 .      Number        SMLIMS
# 4038              .                 .      Number        SMLIMS
# 4039              .                 .      Number        SMLIMS
# 4040              .                 .      Number        SMLIMS
# 4041              .                 .      Number        SMLIMS
# 4042              .                 .      Number        SMLIMS
# 4043              .                 .      Number        SMLIMS
# 4044              .                 .      Number        SMLIMS
# 4045              .                 .      Number        SMLIMS
# 4046              .                 .      Number        SMLIMS
# 4047              .                 .      Number        SMLIMS
# 4048              .                 .      Number        SMLIMS
# 4049              .                 .      Number        SMLIMS
# 4050              .                 .      Number        SMLIMS
# 4051              .                 .      Number        SMLIMS
# 4052              .                 .      Number        SMLIMS
# 4053              .                 .      Number        SMLIMS
# 4054              .                 .      Number        SMLIMS
# 4055              .                 .      Number        SMLIMS
# 4056              .                 .      Number        SMLIMS
# 4057              .                 .      Number        SMLIMS
# 4058              .                 .      Number        SMLIMS
# 4059              .                 .      Number        SMLIMS
# 4060              .                 .      Number        SMLIMS
# 4061              .                 .      Number        SMLIMS
# 4062              .                 .      Number        SMLIMS
#
#      ctrl_violation action_violation rej_violation spec status ctrl status
# 0                 .                .             .         0.0         NaN
# 1                 .                .             .         0.0         NaN
# 2                 .                .             .         0.0         NaN
# 3                 .                .             .         0.0         NaN
# 4                 .                .             .         0.0         NaN
# 5                 .                .             .         0.0         NaN
# 6                 .                .             .         0.0         NaN
# 7                 .                .             .         0.0         NaN
# 8                 .                .             .         0.0         NaN
# 9                 .                .             .         0.0         NaN
# 10                .                .             .         0.0         NaN
# 11                .                .             .         0.0         NaN
# 12                .                .             .         0.0         NaN
# 13                .                .             .         0.0         NaN
# 14                .                .             .         0.0         NaN
# 15                .                .             .         0.0         NaN
# 16                .                .             .         0.0         NaN
# 17                .                .             .         0.0         NaN
# 18                .                .             .         0.0         NaN
# 19                .                .             .         0.0         NaN
# 20                .                .             .         0.0         NaN
# 21                .                .             .         0.0         NaN
# 22                .                .             .         0.0         NaN
# 23                .                .             .         0.0         NaN
# 24                .                .             .         0.0         NaN
# 25                .                .             .         0.0         NaN
# 26                .                .             .         0.0         NaN
# 27                .                .             .         0.0         NaN
# 28                .                .             .         0.0         NaN
# 29                .                .             .         0.0         NaN
# ...             ...              ...           ...         ...         ...
# 4033              .                .             .        -1.0         NaN
# 4034              .                .             .        -1.0         NaN
# 4035              .                .             .        -1.0         NaN
# 4036              .                .             .        -1.0         NaN
# 4037              .                .             .        -1.0         NaN
# 4038              .                .             .         0.0         NaN
# 4039              .                .             .         0.0         NaN
# 4040              .                .             .         0.0         NaN
# 4041              .                .             .         0.0         0.0
# 4042              .                .             .         0.0         0.0
# 4043              .                .             .         0.0         0.0
# 4044              .                .             .         0.0         0.0
# 4045              .                .             .         0.0         NaN
# 4046              .                .             .         0.0         NaN
# 4047              .                .             .         0.0         NaN
# 4048              .                .             .         0.0         NaN
# 4049              .                .             .         0.0         NaN
# 4050              .                .             .         0.0         0.0
# 4051              .                .             .         0.0         0.0
# 4052              .                .             .         0.0         0.0
# 4053              .                .             .         0.0         0.0
# 4054              .                .             .         0.0         0.0
# 4055              .                .             .         0.0         0.0
# 4056              .                .             .         0.0         0.0
# 4057              .                .             .         0.0         0.0
# 4058              .                .             .         0.0         NaN
# 4059              .                .             .         0.0         NaN
# 4060              .                .             .         0.0         NaN
# 4061              .                .             .         0.0         0.0
# 4062              .                .             .         0.0         0.0
#
# [4063 rows x 40 columns]

# %%
immu=pd.read_csv("normal_stats_output_all_Oct11.csv")

# %%
test["LAL"]=pd.to_numeric(test.LAL,errors="ignore")
test["UAL"]=pd.to_numeric(test.UAL,errors="ignore")

# %%
aranesp=pd.read_excel("query-impala-154041.xlsx")

# %%
para_unit_pair_df=para_unit_combi_df(test)

# %%
aranesp=aranesp.rename(columns={"ual":"UAL","lal":"LAL","lcl":"LCL","ucl":"UCL"})

# %%
spec_correction_rawset(aranesp,para_unit_pair_df)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
 aranesp[(aranesp["parameter name"]=="Isoelectric Focusing: Isoforms 19 + 20")&(aranesp["unit procedure"]=="PRJU:APR6-DS-AML")]["UAL"]
# Out:
# 5610    43
# 5611    43
# 5612    43
# 5613    43
# 5614    43
# 5615    43
# 5616    43
# 5617    43
# 5618    43
# 5619    43
# 5620    43
# 5621    43
# 5622    43
# 5623    43
# 5624    43
# 5625    43
# 5626    43
# 5627    43
# 5628    43
# 5629    43
# 5630    43
# 5631    43
# 5632    43
# 5633    43
# 5634    43
# 5635    43
# 5636    43
# 5637    43
# 5638    43
# 5639    43
# Name: UAL, dtype: object

# %%
tttt()[0]
df1.groupby(['A','B']).size()
# Out:
# 1
